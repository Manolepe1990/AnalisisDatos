# %% [markdown]
# Ejercicio de regresion lineal

# %%
#Librerias_datos
import pandas as pd
import numpy as np
import os

#Librerias_graficos
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %%
# Defino el rango de datos

lineal = pd.read_csv("C:\python\lineal\data.csv", sep = ",")

# %%
#Imprimo los datos
lineal
# Out:
#    metro  precio
# 0      5     375
# 1     15     487
# 2     20     450
# 3     25     500

# %%
# Grafica de dispersion
lineal.plot.scatter(x= "metro", y = "precio")
plt.show()

# %%
#Analisis de regresión
regresion = linear_model.LinearRegression()

#Creo el arreglo y defino las variables
metros = lineal["metro"].values.reshape((-1,1))
X = lineal[['metro']]
y = lineal['precio']

#Creo el modelo de regresión
modelo = regresion.fit(metros, lineal["precio"])

print("Interseccion (b)", modelo.intercept_)

#Se obtiene la pendiente
print("Pendiente (m)", modelo.coef_)

#Predicciones
predicciones = modelo.predict(metros)
print("Prediccion", predicciones)

#Se obtienen los coeficientes
print("Coeficiente:", list(zip(X.columns, modelo.coef_.flatten(), )))
print("Coeficiente de determinación R^2:", modelo.score(X, y))
# Out:
# Interseccion (b) 361.25714285714287
# Pendiente (m) [5.64571429]
# Prediccion [389.48571429 445.94285714 474.17142857 502.4       ]
# Coeficiente: [('metro', 5.645714285714287)]
# Coeficiente de determinación R^2: 0.737202066277981

# %%
#Grafica del modelo
lineal.plot.scatter(x="metro" , y="precio", label = 'Datos base')
plt.scatter(metros, predicciones, color = 'green')
plt.plot(metros, predicciones, color='yellow', label='Linea de regresion')
plt.xlabel('metro')
plt.ylabel('precio')
plt.legend()
plt.show()

# %%
# Correlación lineal entre las variables
corr_var = pearsonr(x = lineal['metro'], y =  lineal['precio'])
print("Coeficiente de correlación de Pearson: ", corr_var[0])
print("P - Valor: ", corr_var[1])
# Out:
# Coeficiente de correlación de Pearson:  0.8586047206240954
# P - Valor:  0.14139527937590457

# %%
# Error de test del modelo 
test = modelo.predict(X = metros)
print(test[0:3,])

rmse = mean_squared_error(
        y_true  = precio,
        y_pred  = test,
        squared = False
       )
print("")
print(f"El error (rmse) de test es: {rmse}")
# Out:
# [389.48571429 445.94285714 474.17142857]
#
# El error (rmse) de test es: 24.927609477960658
